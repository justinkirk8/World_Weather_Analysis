# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import linregress
import time
from datetime import datetime
from citipy import citipy
import requests

#get config variable from folder above
os.chdir("..")
from config import weather_api_key
os.chdir("Weather_Database")

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 751

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_current})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | flinders
# Processing Record 2 of Set 1 | alofi
# Processing Record 3 of Set 1 | san quintin
# Processing Record 4 of Set 1 | narsaq
# Processing Record 5 of Set 1 | ugoofaaru
# Processing Record 6 of Set 1 | albany
# Processing Record 7 of Set 1 | grindavik
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | atar
# Processing Record 10 of Set 1 | acarau
# Processing Record 11 of Set 1 | kapaa
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | lensk
# Processing Record 14 of Set 1 | temaraia
# City not found. Skipping...
# Processing Record 15 of Set 1 | mar del plata
# Processing Record 16 of Set 1 | puerto ayora
# Processing Record 17 of Set 1 | dir
# Processing Record 18 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 19 of Set 1 | barrow
# Processing Record 20 of Set 1 | shimanovsk
# Processing Record 21 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 22 of Set 1 | lovington
# Processing Record 23 of Set 1 | bluff
# Processing Record 24 of Set 1 | yellowknife
# Processing Record 25 of Set 1 | rikitea
# Processing Record 26 of Set 1 | bengkulu
# Processing Record 27 of Set 1 | korla
# Processing Record 28 of Set 1 | hambantota
# Processing Record 29 of Set 1 | new norfolk
# Processing Record 30 of Set 1 | atuona
# Processing Record 31 of Set 1 | east london
# Processing Record 32 of Set 1 | opuwo
# Processing Record 33 of Set 1 | labuhan
# Processing Record 34 of Set 1 | jambi
# Processing Record 35 of Set 1 | bonthe
# Processing Record 36 of Set 1 | dzhusaly
# City not found. Skipping...
# Processing Record 37 of Set 1 | sorvag
# City not found. Skipping...
# Processing Record 38 of Set 1 | cidreira
# Processing Record 39 of Set 1 | qaanaaq
# Processing Record 40 of Set 1 | ezequiel montes
# Processing Record 41 of Set 1 | skjervoy
# Processing Record 42 of Set 1 | homburg
# Processing Record 43 of Set 1 | cape town
# Processing Record 44 of Set 1 | atambua
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | mataura
# Processing Record 47 of Set 1 | hilo
# Processing Record 48 of Set 1 | san carlos de bariloche
# Processing Record 49 of Set 1 | ekhabi
# Processing Record 50 of Set 1 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 1 of Set 2 | wufeng
# Processing Record 2 of Set 2 | bredasdorp
# Processing Record 3 of Set 2 | saint george
# Processing Record 4 of Set 2 | padang
# Processing Record 5 of Set 2 | grand centre
# City not found. Skipping...
# Processing Record 6 of Set 2 | butaritari
# Processing Record 7 of Set 2 | yanam
# Processing Record 8 of Set 2 | svetlyy
# Processing Record 9 of Set 2 | flin flon
# Processing Record 10 of Set 2 | bethel
# Processing Record 11 of Set 2 | port-cartier
# Processing Record 12 of Set 2 | bermejo
# Processing Record 13 of Set 2 | vaini
# Processing Record 14 of Set 2 | bam
# Processing Record 15 of Set 2 | kikwit
# Processing Record 16 of Set 2 | byron bay
# Processing Record 17 of Set 2 | norman wells
# Processing Record 18 of Set 2 | dandong
# Processing Record 19 of Set 2 | batagay-alyta
# Processing Record 20 of Set 2 | tuktoyaktuk
# Processing Record 21 of Set 2 | sola
# Processing Record 22 of Set 2 | bukama
# Processing Record 23 of Set 2 | sturgis
# Processing Record 24 of Set 2 | komsomolskoye
# Processing Record 25 of Set 2 | yar-sale
# Processing Record 26 of Set 2 | leningradskiy
# Processing Record 27 of Set 2 | san patricio
# Processing Record 28 of Set 2 | avarua
# Processing Record 29 of Set 2 | dikson
# Processing Record 30 of Set 2 | arraial do cabo
# Processing Record 31 of Set 2 | pangai
# Processing Record 32 of Set 2 | erenhot
# Processing Record 33 of Set 2 | ponta do sol
# Processing Record 34 of Set 2 | hithadhoo
# Processing Record 35 of Set 2 | thompson
# Processing Record 36 of Set 2 | lebu
# Processing Record 37 of Set 2 | hasaki
# Processing Record 38 of Set 2 | isiro
# Processing Record 39 of Set 2 | hermanus
# Processing Record 40 of Set 2 | lagoa
# Processing Record 41 of Set 2 | godhra
# Processing Record 42 of Set 2 | saleaula
# City not found. Skipping...
# Processing Record 43 of Set 2 | kushima
# Processing Record 44 of Set 2 | senador jose porfirio
# Processing Record 45 of Set 2 | constitucion
# Processing Record 46 of Set 2 | nikolskoye
# Processing Record 47 of Set 2 | kudat
# Processing Record 48 of Set 2 | damietta
# Processing Record 49 of Set 2 | kiama
# Processing Record 50 of Set 2 | eyl
# Processing Record 1 of Set 3 | tilichiki
# Processing Record 2 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 3 of Set 3 | vila franca do campo
# Processing Record 4 of Set 3 | umm kaddadah
# Processing Record 5 of Set 3 | georgetown
# Processing Record 6 of Set 3 | novobelokatay
# Processing Record 7 of Set 3 | makaha
# Processing Record 8 of Set 3 | volnovakha
# Processing Record 9 of Set 3 | kruisfontein
# Processing Record 10 of Set 3 | eidsvag
# Processing Record 11 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 12 of Set 3 | zhanaozen
# Processing Record 13 of Set 3 | dublin
# Processing Record 14 of Set 3 | grand gaube
# Processing Record 15 of Set 3 | poum
# Processing Record 16 of Set 3 | carballo
# Processing Record 17 of Set 3 | brigantine
# Processing Record 18 of Set 3 | sitka
# Processing Record 19 of Set 3 | usinsk
# Processing Record 20 of Set 3 | fort nelson
# Processing Record 21 of Set 3 | katha
# City not found. Skipping...
# Processing Record 22 of Set 3 | hami
# Processing Record 23 of Set 3 | carnarvon
# Processing Record 24 of Set 3 | luoyang
# Processing Record 25 of Set 3 | ostrovnoy
# Processing Record 26 of Set 3 | biltine
# Processing Record 27 of Set 3 | tsihombe
# City not found. Skipping...
# Processing Record 28 of Set 3 | kidal
# Processing Record 29 of Set 3 | kodinsk
# Processing Record 30 of Set 3 | soe
# Processing Record 31 of Set 3 | angoche
# Processing Record 32 of Set 3 | yumen
# Processing Record 33 of Set 3 | acapulco
# Processing Record 34 of Set 3 | katsuura
# Processing Record 35 of Set 3 | esperance
# Processing Record 36 of Set 3 | beyneu
# Processing Record 37 of Set 3 | saskylakh
# Processing Record 38 of Set 3 | port alfred
# Processing Record 39 of Set 3 | taltal
# Processing Record 40 of Set 3 | nouadhibou
# Processing Record 41 of Set 3 | jamestown
# Processing Record 42 of Set 3 | zhigansk
# Processing Record 43 of Set 3 | broken hill
# Processing Record 44 of Set 3 | nome
# Processing Record 45 of Set 3 | gilgit
# Processing Record 46 of Set 3 | isangel
# Processing Record 47 of Set 3 | jackson
# Processing Record 48 of Set 3 | fairbanks
# Processing Record 49 of Set 3 | hobart
# Processing Record 50 of Set 3 | kaitangata
# Processing Record 1 of Set 4 | khani
# Processing Record 2 of Set 4 | nyurba
# Processing Record 3 of Set 4 | tiarei
# Processing Record 4 of Set 4 | sao joao da barra
# Processing Record 5 of Set 4 | portland
# Processing Record 6 of Set 4 | severo-kurilsk
# Processing Record 7 of Set 4 | berlevag
# Processing Record 8 of Set 4 | balykshi
# Processing Record 9 of Set 4 | caconda
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | kahului
# Processing Record 12 of Set 4 | provideniya
# Processing Record 13 of Set 4 | verkhnyaya inta
# Processing Record 14 of Set 4 | porto walter
# Processing Record 15 of Set 4 | cabo san lucas
# Processing Record 16 of Set 4 | longyearbyen
# Processing Record 17 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 18 of Set 4 | pingdu
# Processing Record 19 of Set 4 | bambous virieux
# Processing Record 20 of Set 4 | palasa
# Processing Record 21 of Set 4 | cherskiy
# Processing Record 22 of Set 4 | saint anthony
# Processing Record 23 of Set 4 | north bend
# Processing Record 24 of Set 4 | camana
# Processing Record 25 of Set 4 | marzuq
# Processing Record 26 of Set 4 | berzasca
# Processing Record 27 of Set 4 | guozhen
# Processing Record 28 of Set 4 | jalu
# Processing Record 29 of Set 4 | rocha
# Processing Record 30 of Set 4 | gigmoto
# Processing Record 31 of Set 4 | sembakung
# Processing Record 32 of Set 4 | prachuap khiri khan
# Processing Record 33 of Set 4 | port macquarie
# Processing Record 34 of Set 4 | grafton
# Processing Record 35 of Set 4 | tarudant
# City not found. Skipping...
# Processing Record 36 of Set 4 | krasnorechenskiy
# Processing Record 37 of Set 4 | chuy
# Processing Record 38 of Set 4 | nakasongola
# Processing Record 39 of Set 4 | calabozo
# Processing Record 40 of Set 4 | chapais
# Processing Record 41 of Set 4 | port elizabeth
# Processing Record 42 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 4 | jiuquan
# Processing Record 44 of Set 4 | bilma
# Processing Record 45 of Set 4 | hit
# Processing Record 46 of Set 4 | kalmunai
# Processing Record 47 of Set 4 | guerrero negro
# Processing Record 48 of Set 4 | cap malheureux
# Processing Record 49 of Set 4 | ippy
# Processing Record 50 of Set 4 | kodiak
# Processing Record 1 of Set 5 | yuncheng
# Processing Record 2 of Set 5 | wagar
# Processing Record 3 of Set 5 | san pedro
# Processing Record 4 of Set 5 | clermont
# Processing Record 5 of Set 5 | djambala
# Processing Record 6 of Set 5 | faya
# Processing Record 7 of Set 5 | camacha
# Processing Record 8 of Set 5 | la rioja
# Processing Record 9 of Set 5 | bonavista
# Processing Record 10 of Set 5 | biak
# Processing Record 11 of Set 5 | tessalit
# Processing Record 12 of Set 5 | khakhea
# Processing Record 13 of Set 5 | vaitupu
# City not found. Skipping...
# Processing Record 14 of Set 5 | parrita
# Processing Record 15 of Set 5 | lindas
# Processing Record 16 of Set 5 | ayr
# Processing Record 17 of Set 5 | crown point
# Processing Record 18 of Set 5 | karratha
# Processing Record 19 of Set 5 | gorlice
# Processing Record 20 of Set 5 | tautira
# Processing Record 21 of Set 5 | broome
# Processing Record 22 of Set 5 | fortuna
# Processing Record 23 of Set 5 | zachagansk
# City not found. Skipping...
# Processing Record 24 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 25 of Set 5 | oranjemund
# Processing Record 26 of Set 5 | aflu
# City not found. Skipping...
# Processing Record 27 of Set 5 | lichinga
# Processing Record 28 of Set 5 | hobyo
# Processing Record 29 of Set 5 | torbay
# Processing Record 30 of Set 5 | talnakh
# Processing Record 31 of Set 5 | dunedin
# Processing Record 32 of Set 5 | rabat
# Processing Record 33 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 34 of Set 5 | panagjuriste
# City not found. Skipping...
# Processing Record 35 of Set 5 | burnie
# Processing Record 36 of Set 5 | prince rupert
# Processing Record 37 of Set 5 | tasiilaq
# Processing Record 38 of Set 5 | barcelos
# Processing Record 39 of Set 5 | port-gentil
# Processing Record 40 of Set 5 | blythe
# Processing Record 41 of Set 5 | belushya guba
# City not found. Skipping...
# Processing Record 42 of Set 5 | upernavik
# Processing Record 43 of Set 5 | grand river south east
# City not found. Skipping...
# Processing Record 44 of Set 5 | guiong
# Processing Record 45 of Set 5 | takapau
# Processing Record 46 of Set 5 | waipawa
# Processing Record 47 of Set 5 | challans
# Processing Record 48 of Set 5 | khatanga
# Processing Record 49 of Set 5 | mullaitivu
# City not found. Skipping...
# Processing Record 50 of Set 5 | evanston
# Processing Record 1 of Set 6 | yaan
# Processing Record 2 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 3 of Set 6 | axim
# Processing Record 4 of Set 6 | kavieng
# Processing Record 5 of Set 6 | lorengau
# Processing Record 6 of Set 6 | castro
# Processing Record 7 of Set 6 | maniitsoq
# Processing Record 8 of Set 6 | ondjiva
# Processing Record 9 of Set 6 | macaboboni
# City not found. Skipping...
# Processing Record 10 of Set 6 | kavaratti
# Processing Record 11 of Set 6 | vanimo
# Processing Record 12 of Set 6 | ilulissat
# Processing Record 13 of Set 6 | malpe
# Processing Record 14 of Set 6 | mananjary
# Processing Record 15 of Set 6 | villazon
# Processing Record 16 of Set 6 | terney
# Processing Record 17 of Set 6 | klaksvik
# Processing Record 18 of Set 6 | timmins
# Processing Record 19 of Set 6 | ybytimi
# City not found. Skipping...
# Processing Record 20 of Set 6 | tura
# Processing Record 21 of Set 6 | rafsanjan
# Processing Record 22 of Set 6 | kamenskoye
# City not found. Skipping...
# Processing Record 23 of Set 6 | oranjestad
# Processing Record 24 of Set 6 | ribeira grande
# Processing Record 25 of Set 6 | saldanha
# Processing Record 26 of Set 6 | kayerkan
# Processing Record 27 of Set 6 | dingle
# Processing Record 28 of Set 6 | whitehorse
# Processing Record 29 of Set 6 | nortelandia
# Processing Record 30 of Set 6 | matias barbosa
# Processing Record 31 of Set 6 | comodoro rivadavia
# Processing Record 32 of Set 6 | shamkhal
# Processing Record 33 of Set 6 | goderich
# Processing Record 34 of Set 6 | zhezkazgan
# Processing Record 35 of Set 6 | amahai
# Processing Record 36 of Set 6 | hamilton
# Processing Record 37 of Set 6 | leh
# Processing Record 38 of Set 6 | lucea
# Processing Record 39 of Set 6 | rodeo
# Processing Record 40 of Set 6 | bud
# Processing Record 41 of Set 6 | sesheke
# Processing Record 42 of Set 6 | asau
# Processing Record 43 of Set 6 | sioux lookout
# Processing Record 44 of Set 6 | nanortalik
# Processing Record 45 of Set 6 | afrikanda
# Processing Record 46 of Set 6 | praya
# Processing Record 47 of Set 6 | hampton
# Processing Record 48 of Set 6 | tuatapere
# Processing Record 49 of Set 6 | zabol
# Processing Record 50 of Set 6 | maiduguri
# Processing Record 1 of Set 7 | hailar
# Processing Record 2 of Set 7 | coruripe
# Processing Record 3 of Set 7 | jardim
# Processing Record 4 of Set 7 | chokurdakh
# Processing Record 5 of Set 7 | anadyr
# Processing Record 6 of Set 7 | vanavara
# Processing Record 7 of Set 7 | zernograd
# Processing Record 8 of Set 7 | saint-philippe
# Processing Record 9 of Set 7 | muli
# Processing Record 10 of Set 7 | bolungarvik
# City not found. Skipping...
# Processing Record 11 of Set 7 | wynyard
# Processing Record 12 of Set 7 | vestmannaeyjar
# Processing Record 13 of Set 7 | pangkalanbuun
# Processing Record 14 of Set 7 | yongan
# Processing Record 15 of Set 7 | talara
# Processing Record 16 of Set 7 | banjar
# Processing Record 17 of Set 7 | grand-santi
# Processing Record 18 of Set 7 | tefe
# Processing Record 19 of Set 7 | bull savanna
# Processing Record 20 of Set 7 | bourail
# Processing Record 21 of Set 7 | aban
# Processing Record 22 of Set 7 | abu jubayhah
# City not found. Skipping...
# Processing Record 23 of Set 7 | pangnirtung
# Processing Record 24 of Set 7 | beni mazar
# Processing Record 25 of Set 7 | aklavik
# Processing Record 26 of Set 7 | yevpatoriya
# Processing Record 27 of Set 7 | gizo
# Processing Record 28 of Set 7 | sibolga
# Processing Record 29 of Set 7 | bereda
# Processing Record 30 of Set 7 | kendari
# Processing Record 31 of Set 7 | cayenne
# Processing Record 32 of Set 7 | yeppoon
# Processing Record 33 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 34 of Set 7 | vichy
# Processing Record 35 of Set 7 | port hardy
# Processing Record 36 of Set 7 | batemans bay
# Processing Record 37 of Set 7 | ko samui
# Processing Record 38 of Set 7 | larap
# Processing Record 39 of Set 7 | sao gabriel da cachoeira
# Processing Record 40 of Set 7 | luba
# Processing Record 41 of Set 7 | codrington
# Processing Record 42 of Set 7 | balkanabat
# Processing Record 43 of Set 7 | asfi
# Processing Record 44 of Set 7 | digby
# Processing Record 45 of Set 7 | maumere
# Processing Record 46 of Set 7 | geraldton
# Processing Record 47 of Set 7 | mountain home
# Processing Record 48 of Set 7 | port moresby
# Processing Record 49 of Set 7 | nacala
# Processing Record 50 of Set 7 | pingzhuang
# Processing Record 1 of Set 8 | iskateley
# Processing Record 2 of Set 8 | barahona
# Processing Record 3 of Set 8 | alekseyevsk
# Processing Record 4 of Set 8 | clyde river
# Processing Record 5 of Set 8 | vila velha
# Processing Record 6 of Set 8 | ransang
# Processing Record 7 of Set 8 | salekhard
# Processing Record 8 of Set 8 | anar darreh
# City not found. Skipping...
# Processing Record 9 of Set 8 | labuan
# Processing Record 10 of Set 8 | yerbogachen
# Processing Record 11 of Set 8 | tuggurt
# City not found. Skipping...
# Processing Record 12 of Set 8 | cravo norte
# Processing Record 13 of Set 8 | shestakovo
# Processing Record 14 of Set 8 | tongren
# Processing Record 15 of Set 8 | caravelas
# Processing Record 16 of Set 8 | dohar
# Processing Record 17 of Set 8 | pevek
# Processing Record 18 of Set 8 | tomatlan
# Processing Record 19 of Set 8 | baruun-urt
# Processing Record 20 of Set 8 | port augusta
# Processing Record 21 of Set 8 | andros town
# Processing Record 22 of Set 8 | samusu
# City not found. Skipping...
# Processing Record 23 of Set 8 | glendive
# Processing Record 24 of Set 8 | coquimbo
# Processing Record 25 of Set 8 | calafell
# Processing Record 26 of Set 8 | moroni
# Processing Record 27 of Set 8 | honiara
# Processing Record 28 of Set 8 | port blair
# Processing Record 29 of Set 8 | itoman
# Processing Record 30 of Set 8 | massa marittima
# Processing Record 31 of Set 8 | vallenar
# Processing Record 32 of Set 8 | naze
# Processing Record 33 of Set 8 | mehran
# Processing Record 34 of Set 8 | ilebo
# Processing Record 35 of Set 8 | marakkanam
# Processing Record 36 of Set 8 | bulawayo
# Processing Record 37 of Set 8 | sulangan
# Processing Record 38 of Set 8 | onega
# Processing Record 39 of Set 8 | komsomolskiy
# Processing Record 40 of Set 8 | moron
# Processing Record 41 of Set 8 | araguaina
# Processing Record 42 of Set 8 | ipixuna
# Processing Record 43 of Set 8 | sedelnikovo
# City not found. Skipping...
# Processing Record 44 of Set 8 | kutum
# Processing Record 45 of Set 8 | can tho
# Processing Record 46 of Set 8 | roberto payan
# City not found. Skipping...
# Processing Record 47 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 48 of Set 8 | sug-aksy
# City not found. Skipping...
# Processing Record 49 of Set 8 | chegem
# Processing Record 50 of Set 8 | yeniseysk
# Processing Record 1 of Set 9 | karatau
# Processing Record 2 of Set 9 | pinega
# Processing Record 3 of Set 9 | gat
# Processing Record 4 of Set 9 | kadykchan
# City not found. Skipping...
# Processing Record 5 of Set 9 | benito juarez
# Processing Record 6 of Set 9 | raudeberg
# Processing Record 7 of Set 9 | airai
# Processing Record 8 of Set 9 | cabra
# Processing Record 9 of Set 9 | acari
# Processing Record 10 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 11 of Set 9 | el tejar
# Processing Record 12 of Set 9 | thinadhoo
# Processing Record 13 of Set 9 | iqaluit
# Processing Record 14 of Set 9 | harvard
# Processing Record 15 of Set 9 | qui nhon
# Processing Record 16 of Set 9 | waingapu
# Processing Record 17 of Set 9 | te anau
# Processing Record 18 of Set 9 | burns lake
# Processing Record 19 of Set 9 | ca mau
# Processing Record 20 of Set 9 | henties bay
# Processing Record 21 of Set 9 | chichester
# Processing Record 22 of Set 9 | sao filipe
# Processing Record 23 of Set 9 | tikheron
# City not found. Skipping...
# Processing Record 24 of Set 9 | achalpur
# Processing Record 25 of Set 9 | kupang
# Processing Record 26 of Set 9 | port hueneme
# Processing Record 27 of Set 9 | morro bay
# Processing Record 28 of Set 9 | qaqortoq
# Processing Record 29 of Set 9 | kailua
# Processing Record 30 of Set 9 | santa cruz
# Processing Record 31 of Set 9 | toftir
# City not found. Skipping...
# Processing Record 32 of Set 9 | passa quatro
# Processing Record 33 of Set 9 | safwah
# City not found. Skipping...
# Processing Record 34 of Set 9 | keuruu
# Processing Record 35 of Set 9 | zhangye
# Processing Record 36 of Set 9 | opobo
# City not found. Skipping...
# Processing Record 37 of Set 9 | khonuu
# City not found. Skipping...
# Processing Record 38 of Set 9 | hofn
# Processing Record 39 of Set 9 | kununurra
# Processing Record 40 of Set 9 | kholm
# Processing Record 41 of Set 9 | kibala
# Processing Record 42 of Set 9 | alice springs
# Processing Record 43 of Set 9 | faanui
# Processing Record 44 of Set 9 | mananara
# Processing Record 45 of Set 9 | paamiut
# Processing Record 46 of Set 9 | yakima
# Processing Record 47 of Set 9 | neiafu
# Processing Record 48 of Set 9 | chunoyar
# Processing Record 49 of Set 9 | cervo
# Processing Record 50 of Set 9 | namatanai
# Processing Record 1 of Set 10 | ferme-neuve
# Processing Record 2 of Set 10 | suicheng
# Processing Record 3 of Set 10 | namie
# Processing Record 4 of Set 10 | auki
# Processing Record 5 of Set 10 | xinyu
# Processing Record 6 of Set 10 | salalah
# Processing Record 7 of Set 10 | evans
# Processing Record 8 of Set 10 | toora-khem
# Processing Record 9 of Set 10 | lang son
# Processing Record 10 of Set 10 | markova
# Processing Record 11 of Set 10 | ambovombe
# Processing Record 12 of Set 10 | nioro
# Processing Record 13 of Set 10 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 10 | wanaka
# Processing Record 15 of Set 10 | richards bay
# Processing Record 16 of Set 10 | puerto escondido
# Processing Record 17 of Set 10 | brae
# Processing Record 18 of Set 10 | mys shmidta
# City not found. Skipping...
# Processing Record 19 of Set 10 | hyeres
# Processing Record 20 of Set 10 | amga
# Processing Record 21 of Set 10 | simala
# Processing Record 22 of Set 10 | port lincoln
# Processing Record 23 of Set 10 | toledo
# Processing Record 24 of Set 10 | thatta
# Processing Record 25 of Set 10 | carauari
# Processing Record 26 of Set 10 | makakilo city
# Processing Record 27 of Set 10 | mahebourg
# Processing Record 28 of Set 10 | kumluca
# Processing Record 29 of Set 10 | bucerias
# Processing Record 30 of Set 10 | taywarah
# Processing Record 31 of Set 10 | galgani
# City not found. Skipping...
# Processing Record 32 of Set 10 | srednekolymsk
# Processing Record 33 of Set 10 | porto novo
# Processing Record 34 of Set 10 | bandarbeyla
# Processing Record 35 of Set 10 | bathsheba
# Processing Record 36 of Set 10 | luocheng
# Processing Record 37 of Set 10 | changping
# Processing Record 38 of Set 10 | orbetello
# Processing Record 39 of Set 10 | ulaanbaatar
# Processing Record 40 of Set 10 | medford
# Processing Record 41 of Set 10 | samarai
# Processing Record 42 of Set 10 | mayo
# Processing Record 43 of Set 10 | sorong
# Processing Record 44 of Set 10 | pisco
# Processing Record 45 of Set 10 | weligama
# Processing Record 46 of Set 10 | wukari
# Processing Record 47 of Set 10 | tiznit
# Processing Record 48 of Set 10 | amarpatan
# Processing Record 49 of Set 10 | puerto del rosario
# Processing Record 50 of Set 10 | mount isa
# Processing Record 1 of Set 11 | ambon
# Processing Record 2 of Set 11 | sharlyk
# Processing Record 3 of Set 11 | maragogi
# Processing Record 4 of Set 11 | zarautz
# Processing Record 5 of Set 11 | pocosol
# Processing Record 6 of Set 11 | birjand
# Processing Record 7 of Set 11 | loei
# Processing Record 8 of Set 11 | panguna
# Processing Record 9 of Set 11 | cassia
# Processing Record 10 of Set 11 | olafsvik
# Processing Record 11 of Set 11 | kenai
# Processing Record 12 of Set 11 | alta floresta
# Processing Record 13 of Set 11 | montemarciano
# Processing Record 14 of Set 11 | thunder bay
# Processing Record 15 of Set 11 | tumannyy
# City not found. Skipping...
# Processing Record 16 of Set 11 | tsienyane
# City not found. Skipping...
# Processing Record 17 of Set 11 | matamoros
# Processing Record 18 of Set 11 | limburg
# Processing Record 19 of Set 11 | macau
# Processing Record 20 of Set 11 | mersing
# Processing Record 21 of Set 11 | tezpur
# Processing Record 22 of Set 11 | marawi
# Processing Record 23 of Set 11 | rio gallegos
# Processing Record 24 of Set 11 | buraydah
# Processing Record 25 of Set 11 | odweyne
# Processing Record 26 of Set 11 | ormara
# Processing Record 27 of Set 11 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 11 | kapuskasing
# Processing Record 29 of Set 11 | malangali
# Processing Record 30 of Set 11 | san andres
# Processing Record 31 of Set 11 | touros
# Processing Record 32 of Set 11 | ankang
# Processing Record 33 of Set 11 | pangoa
# Processing Record 34 of Set 11 | zalesovo
# Processing Record 35 of Set 11 | yulara
# Processing Record 36 of Set 11 | moranbah
# Processing Record 37 of Set 11 | pervomayskiy
# Processing Record 38 of Set 11 | druzhba
# Processing Record 39 of Set 11 | dingalan
# Processing Record 40 of Set 11 | lasa
# Processing Record 41 of Set 11 | tommot
# Processing Record 42 of Set 11 | pafos
# Processing Record 43 of Set 11 | ixtapa
# Processing Record 44 of Set 11 | xining
# Processing Record 45 of Set 11 | veraval
# Processing Record 46 of Set 11 | ushtobe
# Processing Record 47 of Set 11 | yenagoa
# Processing Record 48 of Set 11 | xai-xai
# Processing Record 49 of Set 11 | valparaiso
# Processing Record 50 of Set 11 | liverpool
# Processing Record 1 of Set 12 | tigzirt
# Processing Record 2 of Set 12 | lanzhou
# Processing Record 3 of Set 12 | chagda
# City not found. Skipping...
# Processing Record 4 of Set 12 | praia da vitoria
# Processing Record 5 of Set 12 | payson
# Processing Record 6 of Set 12 | akhalgori
# Processing Record 7 of Set 12 | fengzhen
# Processing Record 8 of Set 12 | los llanos de aridane
# Processing Record 9 of Set 12 | ghanzi
# Processing Record 10 of Set 12 | gubkinskiy
# Processing Record 11 of Set 12 | noumea
# Processing Record 12 of Set 12 | oktyabrskiy
# Processing Record 13 of Set 12 | alyangula
# Processing Record 14 of Set 12 | kjollefjord
# Processing Record 15 of Set 12 | sentyabrskiy
# City not found. Skipping...
# Processing Record 16 of Set 12 | biloela
# Processing Record 17 of Set 12 | santa clara
# Processing Record 18 of Set 12 | attawapiskat
# City not found. Skipping...
# Processing Record 19 of Set 12 | husavik
# Processing Record 20 of Set 12 | erdemli
# Processing Record 21 of Set 12 | butembo
# Processing Record 22 of Set 12 | olinda
# Processing Record 23 of Set 12 | dali
# Processing Record 24 of Set 12 | teya
# Processing Record 25 of Set 12 | perth
# Processing Record 26 of Set 12 | westfield
# Processing Record 27 of Set 12 | mandalgovi
# Processing Record 28 of Set 12 | jijiga
# Processing Record 29 of Set 12 | prince george
# Processing Record 30 of Set 12 | mwinilunga
# Processing Record 31 of Set 12 | molina
# Processing Record 32 of Set 12 | havoysund
# Processing Record 33 of Set 12 | verkhoyansk
# Processing Record 34 of Set 12 | kashan
# Processing Record 35 of Set 12 | black river
# Processing Record 36 of Set 12 | ancud
# Processing Record 37 of Set 12 | catamarca
# Processing Record 38 of Set 12 | pitsunda
# Processing Record 39 of Set 12 | papar
# Processing Record 40 of Set 12 | solnechnyy
# Processing Record 41 of Set 12 | cobija
# Processing Record 42 of Set 12 | mackay
# Processing Record 43 of Set 12 | conceicao do araguaia
# Processing Record 44 of Set 12 | la ronge
# Processing Record 45 of Set 12 | likasi
# Processing Record 46 of Set 12 | clevelandia
# Processing Record 47 of Set 12 | kushmurun
# Processing Record 48 of Set 12 | homer
# Processing Record 49 of Set 12 | mykhaylivka
# Processing Record 50 of Set 12 | salinopolis
# Processing Record 1 of Set 13 | rio amarillo
# Processing Record 2 of Set 13 | lazaro cardenas
# Processing Record 3 of Set 13 | galesong
# Processing Record 4 of Set 13 | bloomington
# Processing Record 5 of Set 13 | kalety
# Processing Record 6 of Set 13 | lata
# Processing Record 7 of Set 13 | galchino
# City not found. Skipping...
# Processing Record 8 of Set 13 | celestun
# Processing Record 9 of Set 13 | nerl
# Processing Record 10 of Set 13 | douentza
# Processing Record 11 of Set 13 | larnaca
# Processing Record 12 of Set 13 | toktogul
# Processing Record 13 of Set 13 | ussuriysk
# Processing Record 14 of Set 13 | kamenka
# Processing Record 15 of Set 13 | harper
# Processing Record 16 of Set 13 | svetlogorsk
# Processing Record 17 of Set 13 | namibe
# Processing Record 18 of Set 13 | ketchikan
# Processing Record 19 of Set 13 | sobolevo
# Processing Record 20 of Set 13 | huaihua
# Processing Record 21 of Set 13 | bluefields
# Processing Record 22 of Set 13 | olavarria
# Processing Record 23 of Set 13 | itaqui
# Processing Record 24 of Set 13 | wanning
# Processing Record 25 of Set 13 | ahipara
# Processing Record 26 of Set 13 | lavrentiya
# Processing Record 27 of Set 13 | zyryanskoye
# Processing Record 28 of Set 13 | borlange
# City not found. Skipping...
# Processing Record 29 of Set 13 | gangotri
# City not found. Skipping...
# Processing Record 30 of Set 13 | shingu
# Processing Record 31 of Set 13 | isla vista
# Processing Record 32 of Set 13 | pekan
# Processing Record 33 of Set 13 | rjukan
# Processing Record 34 of Set 13 | old town
# Processing Record 35 of Set 13 | vilyuysk
# Processing Record 36 of Set 13 | stokmarknes
# Processing Record 37 of Set 13 | wajima
# Processing Record 38 of Set 13 | waddan
# Processing Record 39 of Set 13 | biasca
# Processing Record 40 of Set 13 | andenes
# Processing Record 41 of Set 13 | manica
# Processing Record 42 of Set 13 | kizhinga
# Processing Record 43 of Set 13 | iquique
# Processing Record 44 of Set 13 | kupino
# Processing Record 45 of Set 13 | isoka
# Processing Record 46 of Set 13 | keti bandar
# Processing Record 47 of Set 13 | santa isabel do rio negro
# Processing Record 48 of Set 13 | marsh harbour
# Processing Record 49 of Set 13 | souillac
# Processing Record 50 of Set 13 | haines junction
# Processing Record 1 of Set 14 | kinango
# Processing Record 2 of Set 14 | murgab
# Processing Record 3 of Set 14 | cockburn town
# Processing Record 4 of Set 14 | taizhou
# Processing Record 5 of Set 14 | obudovac
# Processing Record 6 of Set 14 | vila do maio
# Processing Record 7 of Set 14 | mubi
# Processing Record 8 of Set 14 | beibei
# Processing Record 9 of Set 14 | mogadishu
# Processing Record 10 of Set 14 | robertsport
# Processing Record 11 of Set 14 | kabo
# Processing Record 12 of Set 14 | vieste
# Processing Record 13 of Set 14 | burlington
# Processing Record 14 of Set 14 | sao paulo de olivenca
# Processing Record 15 of Set 14 | kilosa
# Processing Record 16 of Set 14 | severnyy
# Processing Record 17 of Set 14 | vikulovo
# Processing Record 18 of Set 14 | vikhorevka
# Processing Record 19 of Set 14 | antalaha
# Processing Record 20 of Set 14 | januaria
# Processing Record 21 of Set 14 | kaeo
# Processing Record 22 of Set 14 | kloulklubed
# Processing Record 23 of Set 14 | sidrolandia
# Processing Record 24 of Set 14 | tiksi
# Processing Record 25 of Set 14 | kindu
# Processing Record 26 of Set 14 | bu salim
# City not found. Skipping...
# Processing Record 27 of Set 14 | beloha
# Processing Record 28 of Set 14 | buckeye
# Processing Record 29 of Set 14 | pacifica
# Processing Record 30 of Set 14 | tiruchchendur
# Processing Record 31 of Set 14 | fuerte olimpo
# Processing Record 32 of Set 14 | tocache
# Processing Record 33 of Set 14 | karymskoye
# Processing Record 34 of Set 14 | gorontalo
# Processing Record 35 of Set 14 | kyren
# Processing Record 36 of Set 14 | bobo dioulasso
# Processing Record 37 of Set 14 | tabiauea
# City not found. Skipping...
# Processing Record 38 of Set 14 | lima
# Processing Record 39 of Set 14 | akureyri
# Processing Record 40 of Set 14 | ialibu
# Processing Record 41 of Set 14 | parli
# Processing Record 42 of Set 14 | biryusinsk
# Processing Record 43 of Set 14 | corumba
# Processing Record 44 of Set 14 | wangqing
# Processing Record 45 of Set 14 | ust-kut
# Processing Record 46 of Set 14 | muisne
# Processing Record 47 of Set 14 | eskasem
# City not found. Skipping...
# Processing Record 48 of Set 14 | chambersburg
# Processing Record 49 of Set 14 | sambava
# Processing Record 50 of Set 14 | hushitai
# Processing Record 1 of Set 15 | vardo
# Processing Record 2 of Set 15 | tibu
# Processing Record 3 of Set 15 | kilindoni
# Processing Record 4 of Set 15 | cianorte
# Processing Record 5 of Set 15 | iki-burul
# Processing Record 6 of Set 15 | derzhavinsk
# Processing Record 7 of Set 15 | toliary
# City not found. Skipping...
# Processing Record 8 of Set 15 | saint-paul
# Processing Record 9 of Set 15 | san jose
# Processing Record 10 of Set 15 | sartana
# Processing Record 11 of Set 15 | iquitos
# Processing Record 12 of Set 15 | lovozero
# Processing Record 13 of Set 15 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 15 | tir pol
# City not found. Skipping...
# Processing Record 15 of Set 15 | pointe michel
# Processing Record 16 of Set 15 | balimo
# City not found. Skipping...
# Processing Record 17 of Set 15 | neman
# Processing Record 18 of Set 15 | bongandanga
# Processing Record 19 of Set 15 | solwezi
# Processing Record 20 of Set 15 | panama city
# Processing Record 21 of Set 15 | necochea
# Processing Record 22 of Set 15 | lobito
# Processing Record 23 of Set 15 | mizdah
# Processing Record 24 of Set 15 | beatrice
# Processing Record 25 of Set 15 | benghazi
# Processing Record 26 of Set 15 | meihekou
# Processing Record 27 of Set 15 | luderitz
# Processing Record 28 of Set 15 | bahawalpur
# Processing Record 29 of Set 15 | pak phanang
# Processing Record 30 of Set 15 | smithers
# Processing Record 31 of Set 15 | gorzow wielkopolski
# Processing Record 32 of Set 15 | areia branca
# Processing Record 33 of Set 15 | assomada
# Processing Record 34 of Set 15 | otane
# Processing Record 35 of Set 15 | dawlatabad
# Processing Record 36 of Set 15 | umm durman
# City not found. Skipping...
# Processing Record 37 of Set 15 | martaban
# Processing Record 38 of Set 15 | filingue
# Processing Record 39 of Set 15 | chiang klang
# Processing Record 40 of Set 15 | ampanihy
# Processing Record 41 of Set 15 | christchurch
# Processing Record 42 of Set 15 | mata
# Processing Record 43 of Set 15 | wawa
# Processing Record 44 of Set 15 | xinpu
# Processing Record 45 of Set 15 | dudinka
# Processing Record 46 of Set 15 | kempsey
# Processing Record 47 of Set 15 | avera
# Processing Record 48 of Set 15 | bilibino
# Processing Record 49 of Set 15 | linhares
# Processing Record 50 of Set 15 | padre paraiso
# Processing Record 1 of Set 16 | vohibinany
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Flinders      AU -34.5833  150.8552     65.37        91          73
# 1        Alofi      NU -19.0595 -169.9187     80.49        89          91
# 2  San Quintin      MX  30.4833 -115.9500     80.20        25          72
# 3       Narsaq      GL  60.9167  -46.0500     37.62        70          39
# 4    Ugoofaaru      MV   5.6667   73.0000     84.54        66          28
# 5       Albany      US  42.6001  -73.9662     56.05        61          65
# 6    Grindavik      IS  63.8424  -22.4338     37.35        48           0
# 7      Ushuaia      AR -54.8000  -68.3000     46.02        65           0
# 8         Atar      MR  20.5169  -13.0499     86.92        10           0
# 9       Acarau      BR  -2.8856  -40.1200     82.09        80          32
#
#    Wind Speed Current Description
# 0        4.00       broken clouds
# 1        3.44     overcast clouds
# 2        8.30       broken clouds
# 3        5.03    scattered clouds
# 4        5.23    scattered clouds
# 5        1.99       broken clouds
# 6        4.61           clear sky
# 7        3.44           clear sky
# 8       10.56           clear sky
# 9       13.15    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = os.path.join("Weather_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
