# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import os
from scipy.stats import linregress
import time
from datetime import datetime
from citipy import citipy
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 777

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description" : city_current})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | sorland
# Processing Record 2 of Set 1 | hilo
# Processing Record 3 of Set 1 | wattegama
# Processing Record 4 of Set 1 | eureka
# Processing Record 5 of Set 1 | sentyabrskiy
# City not found. Skipping...
# Processing Record 6 of Set 1 | tambovka
# Processing Record 7 of Set 1 | cap-chat
# Processing Record 8 of Set 1 | quatre cocos
# Processing Record 9 of Set 1 | port-gentil
# Processing Record 10 of Set 1 | hashtrud
# Processing Record 11 of Set 1 | bluff
# Processing Record 12 of Set 1 | mar del plata
# Processing Record 13 of Set 1 | potchefstroom
# Processing Record 14 of Set 1 | upernavik
# Processing Record 15 of Set 1 | salalah
# Processing Record 16 of Set 1 | hithadhoo
# Processing Record 17 of Set 1 | marcona
# City not found. Skipping...
# Processing Record 18 of Set 1 | arraial do cabo
# Processing Record 19 of Set 1 | kaduy
# Processing Record 20 of Set 1 | tiksi
# Processing Record 21 of Set 1 | pevek
# Processing Record 22 of Set 1 | ushuaia
# Processing Record 23 of Set 1 | shu
# Processing Record 24 of Set 1 | chuy
# Processing Record 25 of Set 1 | kodiak
# Processing Record 26 of Set 1 | grindavik
# Processing Record 27 of Set 1 | tsabong
# Processing Record 28 of Set 1 | rikitea
# Processing Record 29 of Set 1 | hays
# Processing Record 30 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 31 of Set 1 | husavik
# Processing Record 32 of Set 1 | qeshm
# Processing Record 33 of Set 1 | vallenar
# Processing Record 34 of Set 1 | yoichi
# Processing Record 35 of Set 1 | mareeba
# Processing Record 36 of Set 1 | ancud
# Processing Record 37 of Set 1 | cascais
# Processing Record 38 of Set 1 | poum
# Processing Record 39 of Set 1 | neiafu
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | narsaq
# Processing Record 42 of Set 1 | qaanaaq
# Processing Record 43 of Set 1 | chernihiv
# Processing Record 44 of Set 1 | tumannyy
# City not found. Skipping...
# Processing Record 45 of Set 1 | carnarvon
# Processing Record 46 of Set 1 | alice springs
# Processing Record 47 of Set 1 | kapaa
# Processing Record 48 of Set 1 | khandyga
# Processing Record 49 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 50 of Set 1 | santa cruz
# Processing Record 1 of Set 2 | otavi
# Processing Record 2 of Set 2 | kaitangata
# Processing Record 3 of Set 2 | mount gambier
# Processing Record 4 of Set 2 | tuktoyaktuk
# Processing Record 5 of Set 2 | longyearbyen
# Processing Record 6 of Set 2 | changji
# Processing Record 7 of Set 2 | bataipora
# Processing Record 8 of Set 2 | ostrovnoy
# Processing Record 9 of Set 2 | tessalit
# Processing Record 10 of Set 2 | tasiilaq
# Processing Record 11 of Set 2 | fortuna
# Processing Record 12 of Set 2 | new norfolk
# Processing Record 13 of Set 2 | atuona
# Processing Record 14 of Set 2 | saldanha
# Processing Record 15 of Set 2 | busselton
# Processing Record 16 of Set 2 | torbay
# Processing Record 17 of Set 2 | bethel
# Processing Record 18 of Set 2 | uchaly
# Processing Record 19 of Set 2 | los llanos de aridane
# Processing Record 20 of Set 2 | hihifo
# City not found. Skipping...
# Processing Record 21 of Set 2 | bredasdorp
# Processing Record 22 of Set 2 | wa
# City not found. Skipping...
# Processing Record 23 of Set 2 | butaritari
# Processing Record 24 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 2 | chara
# Processing Record 26 of Set 2 | itarema
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | barrow
# Processing Record 29 of Set 2 | lagoa
# Processing Record 30 of Set 2 | port elizabeth
# Processing Record 31 of Set 2 | crotone
# Processing Record 32 of Set 2 | iqaluit
# Processing Record 33 of Set 2 | cidreira
# Processing Record 34 of Set 2 | cape town
# Processing Record 35 of Set 2 | souillac
# Processing Record 36 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 37 of Set 2 | san miguel
# Processing Record 38 of Set 2 | nome
# Processing Record 39 of Set 2 | vaini
# Processing Record 40 of Set 2 | hobart
# Processing Record 41 of Set 2 | ostersund
# Processing Record 42 of Set 2 | bengkulu
# Processing Record 43 of Set 2 | thompson
# Processing Record 44 of Set 2 | maceio
# Processing Record 45 of Set 2 | angoche
# Processing Record 46 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 47 of Set 2 | manta
# Processing Record 48 of Set 2 | chapais
# Processing Record 49 of Set 2 | laguna
# Processing Record 50 of Set 2 | bolshoye sorokino
# City not found. Skipping...
# Processing Record 1 of Set 3 | nizhnevartovsk
# Processing Record 2 of Set 3 | gayny
# Processing Record 3 of Set 3 | dikson
# Processing Record 4 of Set 3 | punta arenas
# Processing Record 5 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 6 of Set 3 | pedro juan caballero
# Processing Record 7 of Set 3 | bose
# Processing Record 8 of Set 3 | leningradskiy
# Processing Record 9 of Set 3 | inuvik
# Processing Record 10 of Set 3 | cherskiy
# Processing Record 11 of Set 3 | giyani
# Processing Record 12 of Set 3 | tabriz
# Processing Record 13 of Set 3 | andenes
# Processing Record 14 of Set 3 | gobindapur
# Processing Record 15 of Set 3 | kynashiv
# Processing Record 16 of Set 3 | topeka
# Processing Record 17 of Set 3 | ocean city
# Processing Record 18 of Set 3 | marfino
# Processing Record 19 of Set 3 | avarua
# Processing Record 20 of Set 3 | wahran
# City not found. Skipping...
# Processing Record 21 of Set 3 | miraflores
# Processing Record 22 of Set 3 | nikolskoye
# Processing Record 23 of Set 3 | kalaiya
# Processing Record 24 of Set 3 | east london
# Processing Record 25 of Set 3 | san patricio
# Processing Record 26 of Set 3 | ternate
# Processing Record 27 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 28 of Set 3 | comodoro rivadavia
# Processing Record 29 of Set 3 | batemans bay
# Processing Record 30 of Set 3 | goderich
# Processing Record 31 of Set 3 | kruisfontein
# Processing Record 32 of Set 3 | katsuura
# Processing Record 33 of Set 3 | saravan
# Processing Record 34 of Set 3 | airai
# Processing Record 35 of Set 3 | nusaybin
# Processing Record 36 of Set 3 | mbour
# Processing Record 37 of Set 3 | egvekinot
# Processing Record 38 of Set 3 | mataura
# Processing Record 39 of Set 3 | pakdasht
# Processing Record 40 of Set 3 | chokurdakh
# Processing Record 41 of Set 3 | tual
# Processing Record 42 of Set 3 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 3 | flagstaff
# Processing Record 44 of Set 3 | castro
# Processing Record 45 of Set 3 | rutland
# Processing Record 46 of Set 3 | leh
# Processing Record 47 of Set 3 | koslan
# Processing Record 48 of Set 3 | sao filipe
# Processing Record 49 of Set 3 | yellowknife
# Processing Record 50 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 1 of Set 4 | praia da vitoria
# Processing Record 2 of Set 4 | sitka
# Processing Record 3 of Set 4 | buqayq
# City not found. Skipping...
# Processing Record 4 of Set 4 | vao
# Processing Record 5 of Set 4 | pathein
# Processing Record 6 of Set 4 | alexandria
# Processing Record 7 of Set 4 | puerto ayora
# Processing Record 8 of Set 4 | lavrentiya
# Processing Record 9 of Set 4 | saint-philippe
# Processing Record 10 of Set 4 | muroto
# Processing Record 11 of Set 4 | bokspits
# City not found. Skipping...
# Processing Record 12 of Set 4 | vila velha
# Processing Record 13 of Set 4 | hermanus
# Processing Record 14 of Set 4 | makakilo city
# Processing Record 15 of Set 4 | bambous virieux
# Processing Record 16 of Set 4 | tabory
# Processing Record 17 of Set 4 | sola
# Processing Record 18 of Set 4 | atar
# Processing Record 19 of Set 4 | dire
# Processing Record 20 of Set 4 | kandrian
# Processing Record 21 of Set 4 | zavetnoye
# Processing Record 22 of Set 4 | muswellbrook
# Processing Record 23 of Set 4 | moroto
# Processing Record 24 of Set 4 | moerai
# Processing Record 25 of Set 4 | waingapu
# Processing Record 26 of Set 4 | norman wells
# Processing Record 27 of Set 4 | saint-pierre
# Processing Record 28 of Set 4 | leshukonskoye
# Processing Record 29 of Set 4 | polovinnoye
# Processing Record 30 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 31 of Set 4 | colwyn bay
# Processing Record 32 of Set 4 | male
# Processing Record 33 of Set 4 | necochea
# Processing Record 34 of Set 4 | san quintin
# Processing Record 35 of Set 4 | kalengwa
# Processing Record 36 of Set 4 | berdigestyakh
# Processing Record 37 of Set 4 | port alfred
# Processing Record 38 of Set 4 | vredendal
# Processing Record 39 of Set 4 | tortoli
# Processing Record 40 of Set 4 | hami
# Processing Record 41 of Set 4 | davila
# Processing Record 42 of Set 4 | geraldton
# Processing Record 43 of Set 4 | mount pleasant
# Processing Record 44 of Set 4 | guerrero negro
# Processing Record 45 of Set 4 | ouargaye
# Processing Record 46 of Set 4 | grand river south east
# City not found. Skipping...
# Processing Record 47 of Set 4 | bagdarin
# Processing Record 48 of Set 4 | caravelas
# Processing Record 49 of Set 4 | shache
# Processing Record 50 of Set 4 | taywarah
# Processing Record 1 of Set 5 | pauini
# Processing Record 2 of Set 5 | ponta do sol
# Processing Record 3 of Set 5 | dunedin
# Processing Record 4 of Set 5 | padang
# Processing Record 5 of Set 5 | jamestown
# Processing Record 6 of Set 5 | georgetown
# Processing Record 7 of Set 5 | monster
# Processing Record 8 of Set 5 | satitoa
# City not found. Skipping...
# Processing Record 9 of Set 5 | kaeo
# Processing Record 10 of Set 5 | irtyshskiy
# Processing Record 11 of Set 5 | opuwo
# Processing Record 12 of Set 5 | danilovka
# Processing Record 13 of Set 5 | ayagoz
# Processing Record 14 of Set 5 | boguchany
# Processing Record 15 of Set 5 | chavakkad
# Processing Record 16 of Set 5 | cayenne
# Processing Record 17 of Set 5 | mitchell
# Processing Record 18 of Set 5 | ginir
# Processing Record 19 of Set 5 | saint george
# Processing Record 20 of Set 5 | hasaki
# Processing Record 21 of Set 5 | camacupa
# Processing Record 22 of Set 5 | aba
# Processing Record 23 of Set 5 | xiuyan
# Processing Record 24 of Set 5 | okato
# Processing Record 25 of Set 5 | westport
# Processing Record 26 of Set 5 | dunkirk
# Processing Record 27 of Set 5 | buraydah
# Processing Record 28 of Set 5 | tacna
# Processing Record 29 of Set 5 | balabac
# Processing Record 30 of Set 5 | burdur
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | vardo
# Processing Record 33 of Set 5 | lompoc
# Processing Record 34 of Set 5 | diamantino
# Processing Record 35 of Set 5 | amderma
# City not found. Skipping...
# Processing Record 36 of Set 5 | dakar
# Processing Record 37 of Set 5 | kuche
# City not found. Skipping...
# Processing Record 38 of Set 5 | sakakah
# Processing Record 39 of Set 5 | vila do maio
# Processing Record 40 of Set 5 | ranau
# Processing Record 41 of Set 5 | hervey bay
# Processing Record 42 of Set 5 | malakal
# Processing Record 43 of Set 5 | khatanga
# Processing Record 44 of Set 5 | richards bay
# Processing Record 45 of Set 5 | provideniya
# Processing Record 46 of Set 5 | clyde
# Processing Record 47 of Set 5 | baeza
# Processing Record 48 of Set 5 | port hardy
# Processing Record 49 of Set 5 | hirara
# Processing Record 50 of Set 5 | vila franca do campo
# Processing Record 1 of Set 6 | chenghai
# Processing Record 2 of Set 6 | isangel
# Processing Record 3 of Set 6 | ola
# Processing Record 4 of Set 6 | sao felix do xingu
# Processing Record 5 of Set 6 | havoysund
# Processing Record 6 of Set 6 | homer
# Processing Record 7 of Set 6 | touros
# Processing Record 8 of Set 6 | belyye stolby
# Processing Record 9 of Set 6 | phalombe
# Processing Record 10 of Set 6 | banon
# Processing Record 11 of Set 6 | kahului
# Processing Record 12 of Set 6 | saint-marc-des-carrieres
# Processing Record 13 of Set 6 | hofn
# Processing Record 14 of Set 6 | kirakira
# Processing Record 15 of Set 6 | bolivar
# Processing Record 16 of Set 6 | okahandja
# Processing Record 17 of Set 6 | paramonga
# Processing Record 18 of Set 6 | fevralsk
# City not found. Skipping...
# Processing Record 19 of Set 6 | matamoros
# Processing Record 20 of Set 6 | duz
# City not found. Skipping...
# Processing Record 21 of Set 6 | loiza
# Processing Record 22 of Set 6 | kefamenanu
# Processing Record 23 of Set 6 | calvinia
# Processing Record 24 of Set 6 | balkanabat
# Processing Record 25 of Set 6 | kokopo
# Processing Record 26 of Set 6 | alpena
# Processing Record 27 of Set 6 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 6 | luanda
# Processing Record 29 of Set 6 | katherine
# Processing Record 30 of Set 6 | maniitsoq
# Processing Record 31 of Set 6 | komatsu
# Processing Record 32 of Set 6 | fort morgan
# Processing Record 33 of Set 6 | yara
# Processing Record 34 of Set 6 | west wendover
# Processing Record 35 of Set 6 | sorong
# Processing Record 36 of Set 6 | araouane
# Processing Record 37 of Set 6 | ribeira grande
# Processing Record 38 of Set 6 | brae
# Processing Record 39 of Set 6 | manado
# Processing Record 40 of Set 6 | indramayu
# Processing Record 41 of Set 6 | lata
# Processing Record 42 of Set 6 | porto walter
# Processing Record 43 of Set 6 | faanui
# Processing Record 44 of Set 6 | vanavara
# Processing Record 45 of Set 6 | shatrovo
# Processing Record 46 of Set 6 | vestmannaeyjar
# Processing Record 47 of Set 6 | sibiti
# Processing Record 48 of Set 6 | middle island
# Processing Record 49 of Set 6 | oyabe
# Processing Record 50 of Set 6 | burica
# City not found. Skipping...
# Processing Record 1 of Set 7 | barranca
# Processing Record 2 of Set 7 | qasigiannguit
# Processing Record 3 of Set 7 | trincomalee
# Processing Record 4 of Set 7 | port macquarie
# Processing Record 5 of Set 7 | raudeberg
# Processing Record 6 of Set 7 | saint-francois
# Processing Record 7 of Set 7 | kavieng
# Processing Record 8 of Set 7 | bubaque
# Processing Record 9 of Set 7 | mount isa
# Processing Record 10 of Set 7 | jiuquan
# Processing Record 11 of Set 7 | puerto colombia
# Processing Record 12 of Set 7 | burnie
# Processing Record 13 of Set 7 | dingle
# Processing Record 14 of Set 7 | emba
# Processing Record 15 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 7 | kijang
# Processing Record 17 of Set 7 | karasburg
# Processing Record 18 of Set 7 | san antero
# Processing Record 19 of Set 7 | okhotsk
# Processing Record 20 of Set 7 | boffa
# Processing Record 21 of Set 7 | jimo
# Processing Record 22 of Set 7 | wageningen
# Processing Record 23 of Set 7 | goldsboro
# Processing Record 24 of Set 7 | babayurt
# Processing Record 25 of Set 7 | kargasok
# Processing Record 26 of Set 7 | saskylakh
# Processing Record 27 of Set 7 | coquimbo
# Processing Record 28 of Set 7 | sioux lookout
# Processing Record 29 of Set 7 | ilulissat
# Processing Record 30 of Set 7 | portree
# Processing Record 31 of Set 7 | omsukchan
# Processing Record 32 of Set 7 | stradella
# Processing Record 33 of Set 7 | port hedland
# Processing Record 34 of Set 7 | baykit
# Processing Record 35 of Set 7 | berlevag
# Processing Record 36 of Set 7 | maholi
# Processing Record 37 of Set 7 | amahai
# Processing Record 38 of Set 7 | broome
# Processing Record 39 of Set 7 | saint-augustin
# Processing Record 40 of Set 7 | voznesenskoye
# Processing Record 41 of Set 7 | hikari
# Processing Record 42 of Set 7 | nemuro
# Processing Record 43 of Set 7 | concarneau
# Processing Record 44 of Set 7 | kaduna
# Processing Record 45 of Set 7 | poronaysk
# Processing Record 46 of Set 7 | khani
# Processing Record 47 of Set 7 | tura
# Processing Record 48 of Set 7 | ormara
# Processing Record 49 of Set 7 | coihaique
# Processing Record 50 of Set 7 | hoquiam
# Processing Record 1 of Set 8 | rocha
# Processing Record 2 of Set 8 | menongue
# Processing Record 3 of Set 8 | cabo san lucas
# Processing Record 4 of Set 8 | deputatskiy
# Processing Record 5 of Set 8 | south sioux city
# Processing Record 6 of Set 8 | ingham
# Processing Record 7 of Set 8 | pamplona
# Processing Record 8 of Set 8 | cootamundra
# Processing Record 9 of Set 8 | abha
# Processing Record 10 of Set 8 | palauig
# Processing Record 11 of Set 8 | benguela
# Processing Record 12 of Set 8 | wajima
# Processing Record 13 of Set 8 | zharkovskiy
# Processing Record 14 of Set 8 | torrington
# Processing Record 15 of Set 8 | komsomolskiy
# Processing Record 16 of Set 8 | ischia
# Processing Record 17 of Set 8 | tupiza
# Processing Record 18 of Set 8 | esperance
# Processing Record 19 of Set 8 | santa maria
# Processing Record 20 of Set 8 | skala fourkas
# Processing Record 21 of Set 8 | artyom
# Processing Record 22 of Set 8 | velikiy ustyug
# Processing Record 23 of Set 8 | tabas
# Processing Record 24 of Set 8 | wanaka
# Processing Record 25 of Set 8 | bairiki
# Processing Record 26 of Set 8 | ngukurr
# City not found. Skipping...
# Processing Record 27 of Set 8 | ngorongoro
# Processing Record 28 of Set 8 | beroroha
# Processing Record 29 of Set 8 | guadalupe y calvo
# Processing Record 30 of Set 8 | tiarei
# Processing Record 31 of Set 8 | santa vitoria do palmar
# Processing Record 32 of Set 8 | hutchinson
# Processing Record 33 of Set 8 | bathsheba
# Processing Record 34 of Set 8 | dongobesh
# Processing Record 35 of Set 8 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 36 of Set 8 | urdzhar
# City not found. Skipping...
# Processing Record 37 of Set 8 | rorvik
# Processing Record 38 of Set 8 | ahipara
# Processing Record 39 of Set 8 | tautira
# Processing Record 40 of Set 8 | mananjary
# Processing Record 41 of Set 8 | novopokrovskaya
# Processing Record 42 of Set 8 | sisimiut
# Processing Record 43 of Set 8 | saint-joseph
# Processing Record 44 of Set 8 | harbour breton
# Processing Record 45 of Set 8 | tyazhinskiy
# Processing Record 46 of Set 8 | keflavik
# Processing Record 47 of Set 8 | mahebourg
# Processing Record 48 of Set 8 | izhma
# Processing Record 49 of Set 8 | te anau
# Processing Record 50 of Set 8 | isiolo
# Processing Record 1 of Set 9 | namatanai
# Processing Record 2 of Set 9 | susehri
# Processing Record 3 of Set 9 | port lincoln
# Processing Record 4 of Set 9 | mandera
# Processing Record 5 of Set 9 | talaya
# Processing Record 6 of Set 9 | malvern
# Processing Record 7 of Set 9 | jiexiu
# Processing Record 8 of Set 9 | grand-santi
# Processing Record 9 of Set 9 | ginda
# Processing Record 10 of Set 9 | sobolevo
# Processing Record 11 of Set 9 | turka
# Processing Record 12 of Set 9 | tutoia
# Processing Record 13 of Set 9 | trelew
# Processing Record 14 of Set 9 | ust-nera
# Processing Record 15 of Set 9 | attawapiskat
# City not found. Skipping...
# Processing Record 16 of Set 9 | conde
# Processing Record 17 of Set 9 | clinton
# Processing Record 18 of Set 9 | san ramon
# Processing Record 19 of Set 9 | morant bay
# Processing Record 20 of Set 9 | doha
# Processing Record 21 of Set 9 | orchard homes
# Processing Record 22 of Set 9 | atasu
# Processing Record 23 of Set 9 | shimoda
# Processing Record 24 of Set 9 | salgado
# Processing Record 25 of Set 9 | denpasar
# Processing Record 26 of Set 9 | carballo
# Processing Record 27 of Set 9 | buta
# Processing Record 28 of Set 9 | nizwa
# Processing Record 29 of Set 9 | mahibadhoo
# Processing Record 30 of Set 9 | aykhal
# Processing Record 31 of Set 9 | mys shmidta
# City not found. Skipping...
# Processing Record 32 of Set 9 | watertown
# Processing Record 33 of Set 9 | krasnoselkup
# Processing Record 34 of Set 9 | avera
# Processing Record 35 of Set 9 | lakeville
# Processing Record 36 of Set 9 | moranbah
# Processing Record 37 of Set 9 | aswan
# Processing Record 38 of Set 9 | waipawa
# Processing Record 39 of Set 9 | matangad
# Processing Record 40 of Set 9 | constitucion
# Processing Record 41 of Set 9 | presidencia roque saenz pena
# Processing Record 42 of Set 9 | tuatapere
# Processing Record 43 of Set 9 | hornepayne
# Processing Record 44 of Set 9 | severo-kurilsk
# Processing Record 45 of Set 9 | borger
# Processing Record 46 of Set 9 | zhuhai
# Processing Record 47 of Set 9 | manono
# Processing Record 48 of Set 9 | qostanay
# Processing Record 49 of Set 9 | mbarara
# Processing Record 50 of Set 9 | terrace
# Processing Record 1 of Set 10 | cockburn town
# Processing Record 2 of Set 10 | daru
# Processing Record 3 of Set 10 | muravlenko
# Processing Record 4 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 5 of Set 10 | stornoway
# Processing Record 6 of Set 10 | tuscaloosa
# Processing Record 7 of Set 10 | farafangana
# Processing Record 8 of Set 10 | yumen
# Processing Record 9 of Set 10 | novosysoyevka
# Processing Record 10 of Set 10 | harlingen
# Processing Record 11 of Set 10 | pitimbu
# Processing Record 12 of Set 10 | eyl
# Processing Record 13 of Set 10 | nantucket
# Processing Record 14 of Set 10 | north bend
# Processing Record 15 of Set 10 | caconda
# Processing Record 16 of Set 10 | victor harbor
# Processing Record 17 of Set 10 | beirut
# Processing Record 18 of Set 10 | lanigan
# Processing Record 19 of Set 10 | bilma
# Processing Record 20 of Set 10 | saurimo
# Processing Record 21 of Set 10 | kamaishi
# Processing Record 22 of Set 10 | nouadhibou
# Processing Record 23 of Set 10 | olafsvik
# Processing Record 24 of Set 10 | udachnyy
# Processing Record 25 of Set 10 | kindu
# Processing Record 26 of Set 10 | piacabucu
# Processing Record 27 of Set 10 | yulara
# Processing Record 28 of Set 10 | cingoli
# Processing Record 29 of Set 10 | big rapids
# Processing Record 30 of Set 10 | nerchinskiy zavod
# Processing Record 31 of Set 10 | miyako
# Processing Record 32 of Set 10 | san cristobal
# Processing Record 33 of Set 10 | lorengau
# Processing Record 34 of Set 10 | springbok
# Processing Record 35 of Set 10 | madang
# Processing Record 36 of Set 10 | new richmond
# Processing Record 37 of Set 10 | bandundu
# Processing Record 38 of Set 10 | thinadhoo
# Processing Record 39 of Set 10 | kashan
# Processing Record 40 of Set 10 | canutama
# Processing Record 41 of Set 10 | alta floresta
# Processing Record 42 of Set 10 | oranjemund
# Processing Record 43 of Set 10 | innisfail
# Processing Record 44 of Set 10 | sal rei
# Processing Record 45 of Set 10 | murbad
# Processing Record 46 of Set 10 | plettenberg bay
# Processing Record 47 of Set 10 | luwuk
# Processing Record 48 of Set 10 | olfen
# Processing Record 49 of Set 10 | vitim
# Processing Record 50 of Set 10 | anar darreh
# City not found. Skipping...
# Processing Record 1 of Set 11 | cienfuegos
# Processing Record 2 of Set 11 | olinda
# Processing Record 3 of Set 11 | belyy yar
# Processing Record 4 of Set 11 | port blair
# Processing Record 5 of Set 11 | kavaratti
# Processing Record 6 of Set 11 | aksu
# Processing Record 7 of Set 11 | ibra
# Processing Record 8 of Set 11 | sechura
# Processing Record 9 of Set 11 | mankono
# Processing Record 10 of Set 11 | kytmanovo
# Processing Record 11 of Set 11 | bandarbeyla
# Processing Record 12 of Set 11 | kolda
# Processing Record 13 of Set 11 | chhachhrauli
# Processing Record 14 of Set 11 | zemio
# Processing Record 15 of Set 11 | suntar
# Processing Record 16 of Set 11 | aljezur
# Processing Record 17 of Set 11 | riyadh
# Processing Record 18 of Set 11 | arshan
# Processing Record 19 of Set 11 | victoria
# Processing Record 20 of Set 11 | severnoye
# Processing Record 21 of Set 11 | otane
# Processing Record 22 of Set 11 | haines junction
# Processing Record 23 of Set 11 | karpathos
# Processing Record 24 of Set 11 | luderitz
# Processing Record 25 of Set 11 | oni
# Processing Record 26 of Set 11 | skjervoy
# Processing Record 27 of Set 11 | zhangye
# Processing Record 28 of Set 11 | oktyabrskiy
# Processing Record 29 of Set 11 | caluquembe
# Processing Record 30 of Set 11 | zhigansk
# Processing Record 31 of Set 11 | pemangkat
# Processing Record 32 of Set 11 | talnakh
# Processing Record 33 of Set 11 | borzya
# Processing Record 34 of Set 11 | salekhard
# Processing Record 35 of Set 11 | sahrak
# City not found. Skipping...
# Processing Record 36 of Set 11 | temaraia
# City not found. Skipping...
# Processing Record 37 of Set 11 | codrington
# Processing Record 38 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 39 of Set 11 | mahon
# Processing Record 40 of Set 11 | ivanivka
# Processing Record 41 of Set 11 | ardistan
# City not found. Skipping...
# Processing Record 42 of Set 11 | kurilsk
# Processing Record 43 of Set 11 | ashtabula
# Processing Record 44 of Set 11 | sabzevar
# Processing Record 45 of Set 11 | hearst
# Processing Record 46 of Set 11 | horsham
# Processing Record 47 of Set 11 | skagastrond
# City not found. Skipping...
# Processing Record 48 of Set 11 | sidi ali
# Processing Record 49 of Set 11 | zaozerne
# Processing Record 50 of Set 11 | proletariy
# Processing Record 1 of Set 12 | mogadishu
# Processing Record 2 of Set 12 | verkhnevilyuysk
# Processing Record 3 of Set 12 | san vicente
# Processing Record 4 of Set 12 | nanakuli
# Processing Record 5 of Set 12 | sibirtsevo
# City not found. Skipping...
# Processing Record 6 of Set 12 | del rio
# Processing Record 7 of Set 12 | quartucciu
# Processing Record 8 of Set 12 | aklavik
# Processing Record 9 of Set 12 | asau
# Processing Record 10 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 11 of Set 12 | abnub
# Processing Record 12 of Set 12 | pangnirtung
# Processing Record 13 of Set 12 | makarov
# Processing Record 14 of Set 12 | yar-sale
# Processing Record 15 of Set 12 | dali
# Processing Record 16 of Set 12 | wajid
# Processing Record 17 of Set 12 | wilmington
# Processing Record 18 of Set 12 | ejura
# Processing Record 19 of Set 12 | dalvik
# Processing Record 20 of Set 12 | chuguyevka
# Processing Record 21 of Set 12 | kristiinankaupunki
# Processing Record 22 of Set 12 | blackwater
# Processing Record 23 of Set 12 | tuzha
# Processing Record 24 of Set 12 | saint-michel-des-saints
# Processing Record 25 of Set 12 | las palmas
# Processing Record 26 of Set 12 | atocha
# Processing Record 27 of Set 12 | brusque
# Processing Record 28 of Set 12 | lasa
# Processing Record 29 of Set 12 | mecca
# Processing Record 30 of Set 12 | castanos
# Processing Record 31 of Set 12 | umea
# Processing Record 32 of Set 12 | tanggu
# Processing Record 33 of Set 12 | tidore
# City not found. Skipping...
# Processing Record 34 of Set 12 | anadyr
# Processing Record 35 of Set 12 | kabwe
# Processing Record 36 of Set 12 | snezhnogorsk
# Processing Record 37 of Set 12 | georgiyevka
# Processing Record 38 of Set 12 | werda
# Processing Record 39 of Set 12 | divnomorskoye
# Processing Record 40 of Set 12 | pedernales
# Processing Record 41 of Set 12 | boca do acre
# Processing Record 42 of Set 12 | manokwari
# Processing Record 43 of Set 12 | aguimes
# Processing Record 44 of Set 12 | manakara
# Processing Record 45 of Set 12 | shahabad
# Processing Record 46 of Set 12 | inirida
# Processing Record 47 of Set 12 | bollnas
# Processing Record 48 of Set 12 | fukue
# Processing Record 49 of Set 12 | oda
# Processing Record 50 of Set 12 | port shepstone
# Processing Record 1 of Set 13 | dromolaxia
# Processing Record 2 of Set 13 | peterhead
# Processing Record 3 of Set 13 | akdepe
# Processing Record 4 of Set 13 | chiang rai
# Processing Record 5 of Set 13 | kodinsk
# Processing Record 6 of Set 13 | makasar
# Processing Record 7 of Set 13 | rognan
# Processing Record 8 of Set 13 | vuktyl
# Processing Record 9 of Set 13 | meridian
# Processing Record 10 of Set 13 | aksarka
# Processing Record 11 of Set 13 | mitsamiouli
# Processing Record 12 of Set 13 | yambio
# Processing Record 13 of Set 13 | calabozo
# Processing Record 14 of Set 13 | qesarya
# Processing Record 15 of Set 13 | mogzon
# Processing Record 16 of Set 13 | karauzyak
# City not found. Skipping...
# Processing Record 17 of Set 13 | pangody
# Processing Record 18 of Set 13 | nguiu
# City not found. Skipping...
# Processing Record 19 of Set 13 | nanton
# Processing Record 20 of Set 13 | klaksvik
# Processing Record 21 of Set 13 | santa marta
# Processing Record 22 of Set 13 | karratha
# Processing Record 23 of Set 13 | villa union
# Processing Record 24 of Set 13 | borba
# Processing Record 25 of Set 13 | jodar
# Processing Record 26 of Set 13 | mbinga
# Processing Record 27 of Set 13 | pisco
# Processing Record 28 of Set 13 | semey
# Processing Record 29 of Set 13 | nanortalik
# Processing Record 30 of Set 13 | belmonte
# Processing Record 31 of Set 13 | killam
# Processing Record 32 of Set 13 | bud
# Processing Record 33 of Set 13 | singkang
# Processing Record 34 of Set 13 | kralendijk
# Processing Record 35 of Set 13 | meadow lake
# Processing Record 36 of Set 13 | tilichiki
# Processing Record 37 of Set 13 | manggar
# Processing Record 38 of Set 13 | naze
# Processing Record 39 of Set 13 | newport
# Processing Record 40 of Set 13 | vostryakovo
# Processing Record 41 of Set 13 | smolenka
# Processing Record 42 of Set 13 | havre-saint-pierre
# Processing Record 43 of Set 13 | babanusah
# City not found. Skipping...
# Processing Record 44 of Set 13 | burns lake
# Processing Record 45 of Set 13 | high level
# Processing Record 46 of Set 13 | ambulu
# Processing Record 47 of Set 13 | huangchuan
# Processing Record 48 of Set 13 | half moon bay
# Processing Record 49 of Set 13 | champerico
# Processing Record 50 of Set 13 | pecos
# Processing Record 1 of Set 14 | halifax
# Processing Record 2 of Set 14 | batagay-alyta
# Processing Record 3 of Set 14 | upata
# Processing Record 4 of Set 14 | meulaboh
# Processing Record 5 of Set 14 | ponta delgada
# Processing Record 6 of Set 14 | zharkent
# Processing Record 7 of Set 14 | alad
# Processing Record 8 of Set 14 | talara
# Processing Record 9 of Set 14 | fort nelson
# Processing Record 10 of Set 14 | gimli
# Processing Record 11 of Set 14 | mountain home
# Processing Record 12 of Set 14 | omboue
# Processing Record 13 of Set 14 | boa vista
# Processing Record 14 of Set 14 | utiroa
# City not found. Skipping...
# Processing Record 15 of Set 14 | paragominas
# Processing Record 16 of Set 14 | mushie
# Processing Record 17 of Set 14 | botwood
# Processing Record 18 of Set 14 | buckingham
# Processing Record 19 of Set 14 | kihei
# Processing Record 20 of Set 14 | argelia
# Processing Record 21 of Set 14 | hun
# Processing Record 22 of Set 14 | juba
# Processing Record 23 of Set 14 | usinsk
# Processing Record 24 of Set 14 | okha
# Processing Record 25 of Set 14 | luganville
# Processing Record 26 of Set 14 | san juan
# Processing Record 27 of Set 14 | kazalinsk
# City not found. Skipping...
# Processing Record 28 of Set 14 | aranos
# Processing Record 29 of Set 14 | nishihara
# Processing Record 30 of Set 14 | mokhsogollokh
# Processing Record 31 of Set 14 | victoria point
# Processing Record 32 of Set 14 | colares
# Processing Record 33 of Set 14 | kokstad
# Processing Record 34 of Set 14 | medicine hat
# Processing Record 35 of Set 14 | kuytun
# Processing Record 36 of Set 14 | pundaguitan
# Processing Record 37 of Set 14 | port augusta
# Processing Record 38 of Set 14 | kirensk
# Processing Record 39 of Set 14 | villarrobledo
# Processing Record 40 of Set 14 | forrest city
# Processing Record 41 of Set 14 | valparaiso
# Processing Record 42 of Set 14 | kushima
# Processing Record 43 of Set 14 | aqtobe
# Processing Record 44 of Set 14 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 14 | yarmouth
# Processing Record 46 of Set 14 | svetlaya
# Processing Record 47 of Set 14 | alofi
# Processing Record 48 of Set 14 | salinas
# Processing Record 49 of Set 14 | peniche
# Processing Record 50 of Set 14 | hammerfest
# Processing Record 1 of Set 15 | taoudenni
# Processing Record 2 of Set 15 | shubarshi
# Processing Record 3 of Set 15 | maraa
# Processing Record 4 of Set 15 | enshi
# Processing Record 5 of Set 15 | astana
# Processing Record 6 of Set 15 | mazagao
# Processing Record 7 of Set 15 | boyolangu
# Processing Record 8 of Set 15 | hualmay
# Processing Record 9 of Set 15 | hengshui
# Processing Record 10 of Set 15 | yamasaki
# Processing Record 11 of Set 15 | asfi
# Processing Record 12 of Set 15 | sept-iles
# Processing Record 13 of Set 15 | beruwala
# Processing Record 14 of Set 15 | vostok
# Processing Record 15 of Set 15 | ewa beach
# Processing Record 16 of Set 15 | misratah
# Processing Record 17 of Set 15 | matay
# Processing Record 18 of Set 15 | golden
# Processing Record 19 of Set 15 | nizhneshilovka
# City not found. Skipping...
# Processing Record 20 of Set 15 | bonito
# Processing Record 21 of Set 15 | shizunai
# Processing Record 22 of Set 15 | tiznit
# Processing Record 23 of Set 15 | kang
# Processing Record 24 of Set 15 | sawakin
# Processing Record 25 of Set 15 | kyren
# Processing Record 26 of Set 15 | kayanza
# Processing Record 27 of Set 15 | sokolo
# Processing Record 28 of Set 15 | zhezkazgan
# Processing Record 29 of Set 15 | vostochnyy
# Processing Record 30 of Set 15 | vila
# Processing Record 31 of Set 15 | saint-louis
# Processing Record 32 of Set 15 | odweyne
# Processing Record 33 of Set 15 | tlalcilalcalpan
# City not found. Skipping...
# Processing Record 34 of Set 15 | inta
# Processing Record 35 of Set 15 | ayan
# Processing Record 36 of Set 15 | jibuti
# Processing Record 37 of Set 15 | cap malheureux
# Processing Record 38 of Set 15 | suez
# Processing Record 39 of Set 15 | pascagoula
# Processing Record 40 of Set 15 | cabral
# Processing Record 41 of Set 15 | flinders
# Processing Record 42 of Set 15 | talaja
# Processing Record 43 of Set 15 | stodolishche
# Processing Record 44 of Set 15 | palmer
# Processing Record 45 of Set 15 | varkkallai
# Processing Record 46 of Set 15 | north battleford
# Processing Record 47 of Set 15 | aflu
# City not found. Skipping...
# Processing Record 48 of Set 15 | bogande
# Processing Record 49 of Set 15 | curup
# Processing Record 50 of Set 15 | yining
# Processing Record 1 of Set 16 | shaowu
# Processing Record 2 of Set 16 | severnyy
# Processing Record 3 of Set 16 | beloha
# Processing Record 4 of Set 16 | zyryanka
# Processing Record 5 of Set 16 | praia
# Processing Record 6 of Set 16 | sakaiminato
# Processing Record 7 of Set 16 | ciudad bolivar
# Processing Record 8 of Set 16 | nyalikungu
# Processing Record 9 of Set 16 | totness
# Processing Record 10 of Set 16 | san carlos de bariloche
# Processing Record 11 of Set 16 | henties bay
# Processing Record 12 of Set 16 | niltepec
# Processing Record 13 of Set 16 | meyungs
# City not found. Skipping...
# Processing Record 14 of Set 16 | qandala
# Processing Record 15 of Set 16 | bonavista
# Processing Record 16 of Set 16 | moron
# Processing Record 17 of Set 16 | chaska
# Processing Record 18 of Set 16 | colombo
# Processing Record 19 of Set 16 | nelson bay
# Processing Record 20 of Set 16 | rondonopolis
# Processing Record 21 of Set 16 | bugene
# Processing Record 22 of Set 16 | epinal
# Processing Record 23 of Set 16 | yellamanchili
# City not found. Skipping...
# Processing Record 24 of Set 16 | ukiah
# Processing Record 25 of Set 16 | pontes e lacerda
# Processing Record 26 of Set 16 | tema
# Processing Record 27 of Set 16 | mizdah
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Sorland      NO  67.6670   12.6934     37.44        56         100
# 1          Hilo      US  19.7297 -155.0900     68.25        96         100
# 2     Wattegama      LK   6.7989   81.4808     76.93        91          99
# 3        Eureka      US  40.8021 -124.1637     51.21        72         100
# 4      Tambovka      RU  50.0969  128.0489     26.62        92          58
# 5      Cap-Chat      CA  49.1001  -66.6821     37.44        89         100
# 6  Quatre Cocos      MU -20.2078   57.7625     78.10        84          59
# 7   Port-Gentil      GA  -0.7193    8.7815     81.43        83          48
# 8      Hashtrud      IR  37.4779   47.0508     55.96        48          61
# 9         Bluff      NZ -46.6000  168.3333     54.86        66          96
#
#    Wind Speed Current Description
# 0       22.46     overcast clouds
# 1        5.75       moderate rain
# 2        1.86     overcast clouds
# 3       10.00     overcast clouds
# 4        1.97       broken clouds
# 5        8.66     overcast clouds
# 6       15.64          light rain
# 7       13.04          light rain
# 8       22.44       broken clouds
# 9       17.45     overcast clouds

# %%
# Create the output file (CSV).
output_data_file = os.path.join("Weather_Database","Weather_Database.csv")
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
